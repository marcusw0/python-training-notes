# %% [markdown]
# # Functions, Variables, and Operators
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %% [markdown]
# ## Built-in Functions

# %%
print("Hello")
# Out:
# Hello

# %%
x = True

# %%
y = False

# %%
print('x and y is:', x and y)
# Out:
# x and y is: False

# %%
print('x or y is:', x or y)
# Out:
# x or y is: True

# %%
print('not x is:', not x)
# Out:
# not x is: False

# %%
print('not y is:', not y)
# Out:
# not y is: True

# %% [markdown]
# ## assinging values to variables

# %%
x = y = z = "Python"

# %%
print(x)
# Out:
# Python

# %%
print(y)
# Out:
# Python

# %%
print(z)
# Out:
# Python

# %%
x = y = z = "Python"

# %%
x = y == z

# %%
print(x)
# Out:
# True

# %%
a, b, c = 5, 3.2, "Hello" # assigns values accordingly by comma (a = 5, b = 3.2)

# %%
print('assigning new variables', "\n")
# Out:
# assigning new variables

# %%
a = 1

# %%
print(a)
# Out:
# 1

# %%
a = a + 1

# %%
print(a)
# Out:
# 2

# %%
a += a + 1 # means addition + assignment (a = 2 from what is above so the using the values of the expression looks like this, 2 += 2 = 1 - will add a + 1 (3), then a + a (2 + 3)

# %%
print(a) #a now equals 5
# Out:
# 5

# %%
a += 10 #simple view of this, take a (5) and adds 10 for the new value of a

# %%
print(a) #15
# Out:
# 15
