# %% [markdown]
# # Calculations
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %% [markdown]
# ## Calculator ###

# %%
7 + 9
# Out:
# 16

# %%
17 - 10
# Out:
# 7

# %%
2 * 6
# Out:
# 12

# %%
10 / 5
# Out:
# 2.0

# %%
10 // 5
# Out:
# 2

# %%
10.5 // 3
# Out:
# 3.0

# %%
2 ** 4 #2 to the power of 4
# Out:
# 16

# %%
50 % 4
# Out:
# 2

# %%
50 % 5
# Out:
# 0

# %%
27.5 + 9.4 + 2
# Out:
# 38.9

# %%
23.6 - 13.6
# Out:
# 10.000000000000002

# %%
27.5 + 9.4 - 13
# Out:
# 23.9

# %%
10 * 5.5
# Out:
# 55.0

# %%
'Hello! ' * 3
# Out:
# 'Hello! Hello! Hello! '

# %%
x = 'awesome'

# %%
print('Python is ' + x)
# Out:
# Python is awesome

# %%
len(x)
# Out:
# 7

# %%
salary = 1000

# %%
rent = 1000

# %%
food = 1

# %%
print(food)
# Out:
# 1

# %%
total = rent + food

# %%
print(total)
# Out:
# 1001

# %%
savings = salary - total

# %%
print('My savings in a year is:', savings)
# Out:
# My savings in a year is: -1
