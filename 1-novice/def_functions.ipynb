# %% [markdown]
# # Def Functions
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %% [markdown]
# ## functions ###

# %%
def my_introduction():
    print("My name is John")
    print("I live in Boston")
    print("I am a data analyst")

# %%
my_introduction() #executes the function
# Out:
# My name is John
# I live in Boston
# I am a data analyst

# %%
def documented_function():
    """ This function does something that is well documented """
    print("Hello")

# %%
print(documented_function)
# Out:
# <function documented_function at 0x7b8699f2a950>

# %%
print(documented_function.__doc__)
# Out:
#  This function does something that is well documented

# %%
def introduction(name):
    print("Hello my name is", name)
    print("I live and work in Dallas")

# %%
introduction("Lily")
# Out:
# Hello my name is Lily
# I live and work in Dallas

# %% [markdown]
# ## Return ##

# %%
def subtract_returns_a_result(num_1, num_2):

    result = num_1 - num_2

    return result

# %%
r = subtract_returns_a_result(5, 10)

# %%
print(r)
# Out:
# -5

# %%
def find_max_in_list(some_list):

    max_element = some_list[0]
    length = len(some_list)

    for i in range(1, length):

        if some_list[i] > max_element:
            max_element = some_list[i]

    return max_element

# %%
num_list = [5, 4, 6, 7, 2, 10, 11, 3]

# %%
max_element = find_max_in_list(num_list)

# %%
print(max_element)
# Out:
# 11
