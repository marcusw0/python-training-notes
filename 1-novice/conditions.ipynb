# %% [markdown]
# # Conditions
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %% [markdown]
# ## Relational operators ##

# %%
10 == 10 #is 10 equal to 10
# Out:
# True

# %%
10 == 20 #False
# Out:
# False

# %%
20 == 'Hello' #False
# Out:
# False

# %%
'Hello' == 'Hello' #True
# Out:
# True

# %%
20 != 20 # is 20 not equal to 20
# Out:
# False

# %%
10 != 20 #True
# Out:
# True

# %%
"Hello" != "Hello" #False
# Out:
# False

# %%
x = 'Hello'

# %%
x == 'Hello' #True
# Out:
# True

# %%
x == "Python" #False
# Out:
# False

# %%
x != "Python" #True
# Out:
# True

# %%
10 < 20 #True
# Out:
# True

# %%
10 < 9 #False
# Out:
# False

# %%
15 > 20 #False
# Out:
# False

# %%
20 <= 15 #False
# Out:
# False

# %%
15 <= 15 #True
# Out:
# True

# %%
10 >= 20 #False
# Out:
# False

# %%
2 + 3 < 6 #Python has order precedence (PEMDAS)
# Out:
# True

# %%
(2 + 3) < 6 #True
# Out:
# True

# %%
2 * 5 > 10 #False
# Out:
# False

# %%
2 * 5 >= 10 #True
# Out:
# True

# %%
40 % 3 == 0 #False
# Out:
# False

# %%
40 % 2 == 0 #True
# Out:
# True

# %% [markdown]
# ## Logical operators ##

# %%
5 > 3 and 4 < 6
# Out:
# True

# %%
(5 > 3) and (4 < 6) #True
# Out:
# True

# %%
5 > 3 and 4 < 2
# Out:
# False

# %%
10 == 10 == True #False 10 == 10 is True 10 == True is False
# Out:
# False

# %%
10 == 10 and 10 == True #False easier way of reading expression above
# Out:
# False

# %%
(10 == 10) == True #True (10 == 10) produces (True) then (True) == True is True
# Out:
# True

# %%
5 > 3 or 4 < 2 #True. or evaluates if either side is True
# Out:
# True

# %%
not(5 > 3 and 4 < 2)
# Out:
# True

# %%
not(5 > 3 or 4 < 6) #False
# Out:
# False
