# %% [markdown]
# # Decorators
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %% [markdown]
# ## Decorators add functionality to existing code WITHOUT modifying the code

# %%
def print_message():
    print("This used decorators!")

# %%
import random

# %%
random.seed(0)

# %%
def highlight():

    annotations = ['-', '*', '+', ':', '^']
    annotate = random.choice(annotations)

    print(annotate * 50)
    print_message()
    print(annotate * 50)

# %%
highlight()
# Out:
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# This used decorators!
# ::::::::::::::::::::::::::::::::::::::::::::::::::

# %%
def print_another_message():
    print("Did you know decorators use closures?")

# %%
highlight()
# Out:
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# This used decorators!
# ::::::::::::::::::::::::::::::::::::::::::::::::::

# %%
def make_highlighted(func):

    annotations = ['-', '*', '+', ':', '^']
    annotate = random.choice(annotations)

    def highlight():
        print(annotate * 50)
        func()
        print(annotate * 50)

    return highlight

# %%
print_message()
# Out:
# This used decorators!

# %%
print_another_message()
# Out:
# Did you know decorators use closures?

# %%
highlight_and_print_message = make_highlighted(print_message)

# %%
highlight_and_print_message()
# Out:
# --------------------------------------------------
# This used decorators!
# --------------------------------------------------

# %%
highlight_and_print_another_message = make_highlighted(print_another_message)

# %%
highlight_and_print_another_message()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Did you know decorators use closures?
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def print_a_third_message():
    print("Now you'll see how decorators are used")

# %%
print_a_third_message()
# Out:
# Now you'll see how decorators are used

# %%
import math

# %%
def area_circle_fn(radius):
    return math.pi * radius * radius

# %%
def perimeter_circle_fn(radius):
    return 2 * math.pi * radius

# %%
def diameter_circle_fn(radius):
    return 2 * radius

# %%
def safe_calculate(func):

    def calculate(r):
        if r <= 0:
            raise ValueError("Radius cannot be negative or zero")
        
        return func(r)
    
    return calculate

# %%
area_circle_safe = safe_calculate(area_circle_fn)  #manually apply safe_calculate to ensure it works

# %%
def area_circle_fn(radius):
    return math.pi * radius * radius

# %%
def perimeter_circle_fn(radius):
    return 2 * math.pi * radius

# %%
print(perimeter_circle_fn(5))
# Out:
# 31.41592653589793

# %%
def area_rectangle_fn(length, breadth):
    return length * breadth

# %%
def safe_calculate_all(func):    #using *args allows multiple positional arguments or just one

    def calculate(*args):

        for arg in args:
            if arg <= 0:
                raise ValueError("Argument cannot be negative or zero")
        
        return func(*args)
    
    return calculate

# %%
def area_rectangle_fn(length, breadth):
    return length * breadth

# %%
print(area_rectangle_fn(5, 4))
# Out:
# 20

# %%
def asterisk_highlight(func):

    def highlight():
        print('*' * 50)
        func()
        print("*"* 50)
    
    return highlight

# %%
def plus_highlight(func):

    def highlight():
        print('+' * 50)
        func()
        print("+" * 50)
    
    return highlight

# %%
def print_message_one():
    print("Message one")

# %%
print_message_one()
# Out:
# Message one

# %%
def print_message_one():
    print("Message one")

# %%
print_message_one()
# Out:
# Message one

# %%
def print_message_one():
    print("Message one")

# %%
print_message_one()
# Out:
# Message one
