# %% [markdown]
# # Importing Modules
#
# Run the cells from top to bottom. Outputs are shown directly below the examples that produce them.

# %%
import math as m

# %%
print("The value of pi is:", m.pi)
# Out:
# The value of pi is: 3.141592653589793

# %%
import sys

# %%
sys.path
# Out:
# ['', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '/home/mwhite84/.local/lib/python3.10/site-packages', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages']

# %%
import time

# %%
print(time.asctime((2024, 1, 2, 3, 4, 5, 1, 2, -1)))
# Out:
# Tue Jan  2 03:04:05 2024

# %%
from time import asctime

# %%
print(asctime((2024, 1, 2, 3, 4, 5, 1, 2, -1)))
# Out:
# Tue Jan  2 03:04:05 2024

# %%
import datetime

# %%
datetime = datetime.datetime(2024, 1, 2, 3, 4, 5)

# %%
print(datetime)
# Out:
# 2024-01-02 03:04:05

# %%
import random

# %%
random.seed(0)

# %%
print(random.__file__)
# Out:
# /usr/lib/python3.10/random.py

# %%
random.random() #random floating point number
# Out:
# 0.8444218515250481

# %%
random.randint(1,100) #random int within the range
# Out:
# 98
