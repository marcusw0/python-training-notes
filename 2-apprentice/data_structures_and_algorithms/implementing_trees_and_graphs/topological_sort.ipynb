# %% [markdown]
# # Topological Sort
#
# Topological sort orders vertices in a directed acyclic graph (DAG) so every prerequisite appears before the work that depends on it. Common use cases include course prerequisites, build pipelines, and task scheduling.

# %%
from queue import Queue
from graph import *

# %% [markdown]
# ## Kahn-style indegree algorithm
#
# The algorithm starts with all vertices that have indegree `0`, removes them from the graph conceptually, and lowers the indegree of their outgoing neighbors. If a graph has a cycle, not every vertex can be emitted.

# %%
def topological_sort(graph):

    queue = Queue()
    indegree_map = {}

    for i in range(graph.num_vertices):
        indegree_map[i] = graph.get_indegree(i)

        if indegree_map[i] == 0:
            queue.put(i)

    sorted_list = []

    while not queue.empty():
        vertex = queue.get()

        sorted_list.append(vertex)

        for v in graph.get_adjacent_vertices(vertex):
            indegree_map[v] = indegree_map[v] - 1

            if indegree_map[v] == 0:
                queue.put(v)


    if len(sorted_list) != graph.num_vertices:
        raise ValueError("This graph has a cycle!")
    
    print(sorted_list)

# %% [markdown]
# ## Directed graph examples
#
# These cells build directed graphs and run topological sort. Compare the order with each edge direction: an edge `u -> v` means `u` should appear before `v`.

# %%
g = AdjacencyMatrixGraph(9, directed=True)

g.add_edge(0, 1)
g.add_edge(0, 2)
g.add_edge(2, 5)
g.add_edge(2, 4)
g.add_edge(2, 3)
g.add_edge(1, 5)
g.add_edge(5, 6)
g.add_edge(7, 3)
g.add_edge(3, 4)
g.add_edge(7, 8)

topological_sort(g)
# Out:
# [0, 7, 1, 2, 8, 3, 5, 4, 6]

# %%
g = AdjacencyMatrixGraph(9, directed=True)

g.add_edge(1, 0)
g.add_edge(2, 0)
g.add_edge(2, 5)
g.add_edge(2, 4)
g.add_edge(2, 3)
g.add_edge(1, 5)
g.add_edge(5, 6)
g.add_edge(7, 3)
g.add_edge(3, 4)
g.add_edge(7, 8)

topological_sort(g)
# Out:
# [1, 2, 7, 0, 5, 3, 8, 6, 4]

# %%
g = AdjacencyMatrixGraph(9, directed=True)

g.add_edge(0, 1)
g.add_edge(0, 2)
g.add_edge(2, 5)
g.add_edge(2, 4)
g.add_edge(2, 3)
g.add_edge(1, 5)
g.add_edge(5, 6)
g.add_edge(7, 3)
g.add_edge(3, 4)
g.add_edge(7, 8)
g.add_edge(5, 0)

topological_sort(g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#      12 g.add_edge(7, 8)
#      13 g.add_edge(5, 0)
# ---> 15 topological_sort(g)
#
# Cell In[8], line 27, in topological_sort(graph)
#      23             queue.put(v)
#      26 if len(sorted_list) != graph.num_vertices:
# ---> 27     raise ValueError("This graph has a cycle!")
#      29 print(sorted_list)
#
# ValueError: This graph has a cycle!
