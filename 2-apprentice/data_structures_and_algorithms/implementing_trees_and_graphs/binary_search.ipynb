# %% [markdown]
# # Binary Search
#
# Binary search finds a value by repeatedly cutting a **sorted** list in half. It is O(log n), but it only works correctly when the input is already sorted in ascending order.

# %%
def binary_search(sorted_list, key):
    min_index = 0
    max_index = len(sorted_list) - 1

    while(min_index <= max_index):
        mid = (min_index + max_index) // 2

        if sorted_list[mid] == key:
            return mid
        elif sorted_list[mid] < key:
            min_index = mid + 1
        else:
            max_index = mid - 1

    return -1

# %% [markdown]
# ## Searching examples
#
# The first two calls find existing values. The final call searches for a missing value, which demonstrates the failure path when the low and high indexes cross.

# %%
num_list = [25, 29, 32, 34, 37, 43, 45, 49, 55, 66, 78, 89, 99]

# %%
binary_search(num_list, 45)
# Out:
# 6

# %%
binary_search(num_list, 32)
# Out:
# 2

# %%
binary_search(num_list, 81)
# Out:
# -1
