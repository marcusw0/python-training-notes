# %% [markdown]
# # Binary Search Tree
#
# A binary search tree (BST) stores smaller or equal values in the left subtree and larger values in the right subtree. This ordering makes lookup, min, max, and sorted traversal efficient when the tree is reasonably balanced.

# %%
class Node:

    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def get_left_child(self):
        return self.left

    def set_left_child(self, left):
        self.left = left

    def get_right_child(self):
        return self.right

    def set_right_child(self, right):
        self.right = right

    def get_value(self):
        return self.data
    
    def set_value(self, value):
        self.data = value

    def print_tree(self):
        if self.left:
            self.left.print_tree()
        print(self.data)

        if self.right:
            self.right.print_tree()

# %% [markdown]
# ## Inserting nodes
#
# Insertion is recursive: compare the new value with the current node, move left or right, and attach the node when an empty child position is found.

# %%
def insert(head, node):

    if head == None:
        return node
    
    if node.get_value() <= head.get_value():
        head.set_left_child(insert(head.get_left_child(), node))
    else:
        head.set_right_child(insert(head.get_right_child(), node))

    return head

# %%
A = Node(45)
B = Node(2)
C = Node(33)
D = Node(54)
E = Node(25)
F = Node(68)
G = Node(72)
H = Node(81)
I = Node(23)

# %%
head = insert(None, E)
head.print_tree()
# Out:
# 25

# %%
insert(head, B)
head.print_tree()
# Out:
# 2
# 25

# %%
insert(head, C)
head.print_tree()
# Out:
# 2
# 25
# 33

# %%
insert(head, I)
insert(head, A)
head.print_tree()
# Out:
# 2
# 23
# 25
# 33
# 45

# %%
insert(head, G)
insert(head, F)
insert(head, D)
insert(head, H)
head.print_tree()
# Out:
# 2
# 23
# 25
# 33
# 45
# 54
# 68
# 72
# 81

# %% [markdown]
# ## Lookup, minimum, and maximum
#
# Lookup follows the same comparisons as insertion. The minimum value lives at the far-left node, and the maximum value lives at the far-right node.

# %%
def lookup(head, data):

    if head == None:
        return print("Value not found!")
    if head.get_value() == data:
        return head
    if data <= head.get_value():
        return lookup(head.get_left_child(), data)
    else:
        return lookup(head.get_right_child(), data)

# %%
def print_node(node):
    if (node == None):
        print("Not found!")
    print(node.get_value())

# %%
print_node(lookup(head, 68))
# Out:
# 68

# %%
print_node(lookup(head, 10))
# Out:
# Value not found!
# Not found!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print_node(lookup(head, 10))
#
# Cell In[24], line 4, in print_node(node)
#       2 if (node == None):
#       3     print("Not found!")
# ----> 4 print(node.get_value())
#
# AttributeError: 'NoneType' object has no attribute 'get_value'

# %%
def min_value(head):
    current = head

    while(current.left != None):
        current = current.left

    return current.data

# %%
min_value(head)
# Out:
# 2

# %%
insert(head, Node(1))
min_value(head)
# Out:
# 1

# %%
def max_value(head):
    current = head

    while(current.right != None):
        current = current.right

    return current.data

# %%
max_value(head)
# Out:
# 81

# %% [markdown]
# Breadth First Traversal

# %% [markdown]
# ## Breadth-first traversal
#
# Breadth-first traversal visits the tree level by level. A queue is the natural helper structure because nodes are processed in the same order they are discovered.

# %%
class MyQueue:

    def __init__(self):

        """ Create a new queue """
        self.items = []

    def is_empty(self):

        """ Returns true if queue is empty """
        return len(self.items) == 0
    
    def enqueue(self, item):

        """ Add a new element to the end of the queue """
        self.items.append(item)

    def dequeue(self):

        """ Remove an element from the beginning of the queue """
        return self.items.pop(0)
    
    def size(self):

        """ Returns the size of the queue """
        return len(self.items)
    
    def peek(self):

        """ Have a look at the first element of the queue """
        if self.is_empty():
            raise Exception("Nothing to peek")

        return self.items[0]

# %%
def breadth_first(node):

    if (node == None):
        raise Exception("No root found!")
    
    path = []
    queue = MyQueue()
    queue.enqueue(node)

    while queue.size() > 0:
        current = queue.dequeue()

        path.append(current.data)

        if current.get_left_child() != None:
            queue.enqueue(current.get_left_child())

        if current.get_right_child() != None:
            queue.enqueue(current.get_right_child())

    return path

# %%
breadth_first(E)
# Out:
# [25, 2, 33, 1, 23, 45, 72, 68, 81, 54]

# %% [markdown]
# Depth First Traversal

# %% [markdown]
# ## Depth-first traversal
#
# Depth-first traversal explores down branches before moving sideways. Pre-order visits root-left-right, in-order visits left-root-right, and post-order visits left-right-root.

# %%
def pre_order(node):
    path = []

    if node:
        path.append(node.data)
        path = path + pre_order(node.get_left_child())
        path = path + pre_order(node.get_right_child())

    return path

# %%
pre_order(E)
# Out:
# [25, 2, 1, 23, 33, 45, 72, 68, 54, 81]

# %%
def in_order(node):
    path = []

    if node:
        path = path + in_order(node.get_left_child())
        path.append(node.data)
        path = path + in_order(node.get_right_child())

    return path

# %%
in_order(E)
# Out:
# [1, 2, 23, 25, 33, 45, 54, 68, 72, 81]

# %%
def post_order(node):
    path = []

    if node:
        path = path + post_order(node.get_left_child())
        path = path + post_order(node.get_right_child())
        path.append(node.data)

    return path

# %%
post_order(E)
# Out:
# [1, 23, 2, 54, 68, 81, 72, 45, 33, 25]
