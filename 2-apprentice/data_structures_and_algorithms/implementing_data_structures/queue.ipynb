# %% [markdown]
# # Queue
#
# A queue is a **first in, first out (FIFO)** data structure. The first item added is the first item removed, like a checkout line, print queue, or task scheduler.

# %%
from queue import Queue

# %% [markdown]
# ## Standard-library queue
#
# `queue.Queue` is useful when you need a bounded or thread-safe queue. The `maxsize` of `5` means this example can hold five countries before `full()` becomes true.

# %%
olympics = Queue(5)
olympics

# %%
olympics.put('United States(USA)')
olympics.put('Great Britain(GBR)')

# %%
olympics.empty()
# Out:
# False

# %%
olympics.full()
# Out:
# False

# %%
olympics.qsize()
# Out:
# 2

# %%
olympics.put('China(CHN)')
olympics.put('Russia(RUS)')
olympics.put('Germany(GER)')

# %%
olympics.empty()
# Out:
# False

# %%
olympics.full()
# Out:
# True

# %%
olympics.qsize()
# Out:
# 5

# %% [markdown]
# ## Dequeueing values
#
# `get()` removes and returns the oldest item. Watch how the queue size changes after each removal: this is the key FIFO behavior.

# %%
olympics.get()
# Out:
# 'United States(USA)'

# %%
olympics.qsize()
# Out:
# 4

# %%
olympics.get()
olympics.get()
olympics.get()
olympics.get()
# Out:
# 'Germany(GER)'

# %%
olympics.empty()
# Out:
# True

# %% [markdown]
# ## Custom queue class
#
# This implementation uses a Python list and exposes the common queue operations: `enqueue`, `dequeue`, `peek`, `size`, and `is_empty`. It is good for learning, but `pop(0)` shifts the remaining list items and costs O(n).

# %%
class MyQueue:

    def __init__(self):
        """ Create a new queue"""
        self.items = []

    def is_empty(self):
        """ Returns true if queue is empty"""
        return len(self.items) == 0
    
    def enqueue(self, item):
        """Add a new element to the end of queue"""
        self.items.append(item)

    def dequeue(self):
        """Remove an element from the beginning of queue"""
        return self.items.pop(0)
    
    def size(self):
        """Returns the size of the queue"""
        return len(self.items)
    
    def peek(self):
        """Look at first element of the queue"""
        if self.is_empty():
            raise Exception("Nothing to peek")
        
        return self.items[0]

# %%
olympics = MyQueue()
olympics

# %%
olympics.enqueue('United States(USA)')
olympics.enqueue('Great Britain(GBR)')

# %%
olympics.items
# Out:
# ['United States(USA)', 'Great Britain(GBR)']

# %%
olympics.peek()
# Out:
# 'United States(USA)'

# %%
olympics.size()
# Out:
# 2

# %%
olympics.enqueue('China(CHN)')
olympics.enqueue('Russia(RUS)')
olympics.enqueue('Germany(GER)')

olympics.size()
# Out:
# 5

# %%
olympics.peek()
# Out:
# 'United States(USA)'

# %%
olympics.dequeue()
# Out:
# 'United States(USA)'

# %%
olympics.peek()
# Out:
# 'Great Britain(GBR)'

# %%
olympics.peek()
# Out:
# 'Great Britain(GBR)'

# %% [markdown]
# ## Empty-queue behavior
#
# The last cells intentionally drain the queue. Calling `dequeue()` or `peek()` after that shows what happens when code tries to read from an empty queue.

# %%
olympics.dequeue()
olympics.dequeue()
olympics.dequeue()
# Out:
# 'Russia(RUS)'

# %%
olympics.peek()
# Out:
# 'Germany(GER)'

# %%
olympics.size()
# Out:
# 1

# %%
olympics.dequeue()
# Out:
# 'Germany(GER)'

# %%
olympics.dequeue()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 olympics.dequeue()
#
# Cell In[25], line 17, in MyQueue.dequeue(self)
#      15 def dequeue(self):
#      16     """Remove an element from the beginning of queue"""
# ---> 17     return self.items.pop(0)
#
# IndexError: pop from empty list

# %%
olympics.peek()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 olympics.peek()
#
# Cell In[25], line 26, in MyQueue.peek(self)
#      24 """Look at first element of the queue"""
#      25 if self.is_empty():
# ---> 26     raise Exception("Nothing to peek")
#      28 return self.items[0]
#
# Exception: Nothing to peek
