# %% [markdown]
# # Singly Linked List
#
# A linked list stores values in separate nodes. Each node holds data and a reference to the next node, so the list grows by changing links instead of shifting array positions.

# %%
class Node:
    """
    A node in a singly-linked list
    """
    def __init__(self, dataval=None, nextval=None):
        self.dataval = dataval
        self.nextval = nextval

    def __repr__(self):
        return repr(self.dataval)

# %% [markdown]
# ## List operations
#
# The `LinkedList` keeps a `head` pointer to the first node. Most operations walk from the head until they find the right location, so traversal is O(n).

# %%
class LinkedList:
    def __init__(self):
        """Creating a new singly-linked list"""
        self.head = None

    def __repr__(self):
        """Creating a string representation of the data in a list"""
        nodes = []
        curr = self.head
        while curr:
            nodes.append(repr(curr))
            curr = curr.nextval
        return '[' + '->'.join(nodes) + ']'
    
    def prepend(self, dataval):
        """Insert a new element at the beginning of the list"""
        self.head = Node(dataval=dataval, nextval=self.head)

    def append(self, dataval):
        """Insert a new element at the end of the list"""
        if not self.head:
            self.head = Node(dataval=dataval)
            return
        curr = self.head
        while curr.nextval:
            curr = curr.nextval
        curr.nextval = Node(dataval=dataval)

    def add_after(self, middle_dataval, dataval):
        """Insert a new element after the node with middle_dataval"""
        if middle_dataval is None:
            print("Data to insert after not specified")
            return
        curr = self.head
        while curr and curr.dataval != middle_dataval:
            curr = curr.nextval
        new_node = Node(dataval=dataval)
        new_node.nextval = curr.nextval
        curr.nextval = new_node

    def find(self, data):
        """Search for the first element with 'dataval' matching
        'data'. Return the element or 'None' if not found."""
        curr = self.head
        while curr and curr.dataval != data:
            curr = curr.nextval

    def remove(self, data):
        """Remove the first occurrence of 'data' in the list"""
        curr = self.head
        prev = None
        while curr and curr.dataval != data:
            prev = curr
            curr = curr.nextval
        if prev is None:
            self.head = curr.nextval
        elif curr:
            prev.nextval = curr.nextval
            curr.nextval = None

    def reverse(self):
        """Reverse the list in-place"""
        curr = self.head
        prev_node = None
        next_node = None
        while curr:
            nextval = curr.nextval
            curr.nextval = prev_node
            prev_node = curr
            curr = nextval
        self.head = prev_node

    def reverse_recursive(self):
        """Reverse the list in-place using recursion"""
        def recursion(curr, prev):
            if not curr:
                return prev
            nextval = curr.nextval
            curr.nextval = prev
            prev = curr
            curr = nextval
            return recursion(curr, prev)
        self.head = recursion(curr=self.head, prev=None)

    def count_nodes(self):
        """Count the number of nodes in the linked list"""
        if (self.head == None):
            return 0
        else:
            curr = self.head
            count = 0
            while (curr != None):
                curr = curr.nextval
                count += 1
        return count

# %% [markdown]
# ## Building a list
#
# These examples show the difference between appending to the tail and prepending to the head. Prepending is constant time because it only changes the head pointer.

# %%
numbers = LinkedList()
numbers
# Out:
# []

# %%
numbers.append("two")
numbers.append("three")
numbers
# Out:
# ['two'->'three']

# %%
numbers.prepend("one")
numbers
# Out:
# ['one'->'two'->'three']

# %%
numbers.append("four")
numbers.append("five")
numbers.append("seven")
numbers
# Out:
# ['one'->'two'->'three'->'four'->'five'->'seven']

# %% [markdown]
# ## Inserting in the middle
#
# `add_after` searches for an existing value and splices the new node into the chain by updating two links.

# %%
numbers.add_after("five", "six")
numbers
# Out:
# ['one'->'two'->'three'->'four'->'five'->'six'->'seven']

# %% [markdown]
# ## Reversing links
#
# Reversal does not create a new list. It walks the existing nodes and points each node back toward the previous node.

# %%
numbers.reverse()
numbers
# Out:
# ['seven'->'six'->'five'->'four'->'three'->'two'->'one']

# %%
numbers.reverse_recursive()
numbers
# Out:
# ['one'->'two'->'three'->'four'->'five'->'six'->'seven']

# %% [markdown]
# ## Removing and counting
#
# Removal needs both `curr` and `prev` pointers: `curr` finds the node to remove, while `prev` reconnects the list around it. Counting walks the whole list once.

# %%
numbers.remove('one')
numbers
# Out:
# ['two'->'three'->'four'->'five'->'six'->'seven']

# %%
numbers.remove('six')
numbers
# Out:
# ['two'->'three'->'four'->'five'->'seven']

# %%
numbers.count_nodes()
# Out:
# 5
