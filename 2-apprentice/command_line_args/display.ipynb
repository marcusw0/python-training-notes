# %%
import argparse
import sys

sys.argv = ["display.py", "-display", "welcome to Loonycorn"]

parser = argparse.ArgumentParser()
parser.add_argument("-display")
args = parser.parse_args()

print(args.display)
# Out:
# welcome to Loonycorn
