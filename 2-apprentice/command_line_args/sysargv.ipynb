# %%
import sys

sys.argv = ["sysargv.py", "loonycorn"]

argument_list = sys.argv
print("The script has the name ", "",
      (sys.argv[0]), "")
print("Number of arguments is",
      (len(sys.argv)))
print("The Arguments are",
      argument_list)
# Out:
# The script has the name   sysargv.py
# Number of arguments is 2
# The Arguments are ['sysargv.py', 'loonycorn']
