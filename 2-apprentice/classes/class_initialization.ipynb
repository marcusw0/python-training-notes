# %%
class Student:
    def __init__(self):
        print("Initialize called!")

s1 = Student()
s2 = Student()
s3 = Student()
# Out:
# Initialize called!
# Initialize called!
# Initialize called!

# %%
class Student:
    def __init__():
        print("Initialize called!")

try:
    s1 = Student()
except TypeError as error:
    print(type(error).__name__ + ':', error)
# Out:
# TypeError: Student.__init__() takes 0 positional arguments but 1 was given

# %%
class Student:
    def __init__(boo):
        print("Initialize called!")

s1 = Student()
# Out:
# Initialize called!

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.mail = name + '.' + '@xyz.com'

s1 = Student('Michel')
print(s1.name, s1.mail)

s2 = Student("Chad")
print(s2.name, s2.mail)

s1.name = 'Michael'
print(s1.name, s1.mail)
# Out:
# Michel Michel.@xyz.com
# Chad Chad.@xyz.com
# Michael Michel.@xyz.com

# %%
class Student:
    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.mail = first + '.' + last + "@xyz.com"

    def fullname(self):
        return '{} {}'.format(self.first, self.last)

s1 = Student("Rodrigo", "Joseph")
print(s1.fullname())
print(s1.fullname)

s2 = Student("Anthony", "Hopkins")
print(s2.fullname())
print(Student.fullname(s2))

print(Student.fullname(s1))
# Out:
# Rodrigo Joseph
# <bound method Student.fullname of <__main__.Student object at 0x7d8daa2fb3d0>>
# Anthony Hopkins
# Anthony Hopkins
# Rodrigo Joseph

# %%
s3 = Student("James", "Miller")
print(s3.first)
del s3.first
print(s3.last)

del s3
# Out:
# James
# Miller

# %%
class Student:
    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.mail = first + '.' + last + "@xyz.com"

    def fullname(self):
        return '{} {}'.format(self.first, self.last)

    def uppercase(self):
        self.first = self.first.upper()
        self.last = self.last.upper()


s1 = Student('Anthony', 'Hopkins')
s2 = Student('John', 'Smith')

print(s1.fullname())
print(s2.fullname())

s1.uppercase()
print(s1.fullname())
# Out:
# Anthony Hopkins
# John Smith
# ANTHONY HOPKINS
